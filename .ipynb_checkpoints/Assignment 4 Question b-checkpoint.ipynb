# %% [markdown]
# # b) Create two time series: one a count of movies released by month-year (Jan-1990, Feb-1990, etc.), the other those movies' average profitability. Plot both series either in two aligned subplots or in a single subplot with a secondary axis. (10 points)

# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv("moviedata.csv", sep='\t')

# %%
movies.head()
# Out:
#   Release_Date                                     Movie  Distributor  \
# 0     03/09/12                               John Carter          NaN
# 1     05/25/07  Pirates of the Caribbean: At World's End  Buena Vista
# 2     12/13/13          The Hobbit: There and Back Again     New Line
# 3     12/14/12         The Hobbit: An Unexpected Journey     New Line
# 4     11/24/10                                   Tangled  Buena Vista
#
#       Budget   US Gross Worldwide Gross
# 0  300000000   66439100       254439100
# 1  300000000  309420425       960996492
# 2  270000000    Unknown         Unknown
# 3  270000000    Unknown         Unknown
# 4  260000000  200821936       586581936

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3627 entries, 0 to 3626
# Data columns (total 6 columns):
# Release_Date       3627 non-null object
# Movie              3627 non-null object
# Distributor        2968 non-null object
# Budget             3627 non-null int64
# US Gross           3627 non-null object
# Worldwide Gross    3627 non-null object
# dtypes: int64(1), object(5)
# memory usage: 170.1+ KB

# %%
# We only need date, month and year 
# A count of how many released
# Average profitability for those movies.

# %%
def make_date(date_str):
    m, d, y = date_str.split('/')
    m = int(m)
    d = int(d)
    y = int(y)
    if y > 13:
        y += 1900
    else:
        y += 2000
    return dt.datetime(y, m, d)

# %%
movies = pd.read_csv("moviedata.csv", sep='\t', parse_dates=[0], date_parser=make_date)

# %%
movies.head()
# Out:
#   Release_Date                                     Movie  Distributor  \
# 0   2012-03-09                               John Carter          NaN
# 1   2007-05-25  Pirates of the Caribbean: At World's End  Buena Vista
# 2   2013-12-13          The Hobbit: There and Back Again     New Line
# 3   2012-12-14         The Hobbit: An Unexpected Journey     New Line
# 4   2010-11-24                                   Tangled  Buena Vista
#
#       Budget   US Gross Worldwide Gross  Month_Year
# 0  300000000   66439100       254439100   (3, 2010)
# 1  300000000  309420425       960996492   (5, 2000)
# 2  270000000    Unknown         Unknown  (12, 2010)
# 3  270000000    Unknown         Unknown  (12, 2010)
# 4  260000000  200821936       586581936  (11, 2010)

# %%
def get_month_year(date):
    year = date.year
    month = date.month
    return month, year

# %%
movies["Month,Year"] = movies.Release_Date.apply(get_month_year)

# %%
movies.head()
# Out:
#   Release_Date                                     Movie  Distributor  \
# 0   2012-03-09                               John Carter          NaN
# 1   2007-05-25  Pirates of the Caribbean: At World's End  Buena Vista
# 2   2013-12-13          The Hobbit: There and Back Again     New Line
# 3   2012-12-14         The Hobbit: An Unexpected Journey     New Line
# 4   2010-11-24                                   Tangled  Buena Vista
#
#       Budget   US Gross Worldwide Gross  Month_Year  Month,Year
# 0  300000000   66439100       254439100   (3, 2010)   (3, 2012)
# 1  300000000  309420425       960996492   (5, 2000)   (5, 2007)
# 2  270000000    Unknown         Unknown  (12, 2010)  (12, 2013)
# 3  270000000    Unknown         Unknown  (12, 2010)  (12, 2012)
# 4  260000000  200821936       586581936  (11, 2010)  (11, 2010)

# %%
movies[movies["Month,Year"]== (5,2007)]
# Out:
#      Release_Date                                     Movie       Distributor  \
# 1      2007-05-25  Pirates of the Caribbean: At World's End       Buena Vista
# 5      2007-05-04                              Spider-Man 3              Sony
# 55     2007-05-18                           Shrek the Third    DreamWorks SKG
# 650    2007-05-04                                 Lucky You      Warner Bros.
# 1800   2007-05-11                              Georgia Rule               NaN
# 2074   2007-05-11                            28 Weeks Later  20th Century Fox
# 2186   2007-05-04                          Paris, je t'aime        First Look
# 2585   2007-05-18                   The Wendell Baker Story               NaN
# 2588   2007-05-11                            Brooklyn Rules       Lion's Gate
# 2959   2007-05-25                                       Bug       Lion's Gate
# 3296   2007-05-02                                  Waitress   Fox Searchlight
# ...

# %%
# Groupby month and year.

# %%
movies["Month,Year"].min()
# Out:
# (1, 1925)

# %%
movies["Month,Year"].max()
# Out:
# (12, 2013)

# %%
#by_month_year = movies.groupby("Month,Year")

# %%
#print(by_month_year.groups.keys())

# %%
by_month_year = movies["Month,Year"]

# %%
by_month_year.sort_values(ascending=True)
# Out:
# 3539     (1, 1925)
# 2968     (1, 1930)
# 3511     (1, 1934)
# 3210     (1, 1938)
# 3268     (1, 1938)
# 3129     (1, 1939)
# 3303     (1, 1939)
# 3321     (1, 1940)
# 3230     (1, 1940)
# 3349     (1, 1943)
# 3163     (1, 1944)
# 3298     (1, 1945)
# 3172     (1, 1945)
# 3325     (1, 1945)
# 3200     (1, 1946)
# 3054     (1, 1946)
# 3226     (1, 1947)
# 3075     (1, 1948)
# 3006     (1, 1948)
# 3278     (1, 1949)
# 3395     (1, 1949)
# 3433     (1, 1952)
# 2965     (1, 1952)
# 3323     (1, 1953)
# 2886     (1, 1954)
# 2914     (1, 1956)
# 2939     (1, 1956)
# 3387     (1, 1956)
# 2777     (1, 1956)
# 2853     (1, 1957)
#            ...
# 14      (12, 2010)
# 210     (12, 2010)
# 2861    (12, 2010)
# 2744    (12, 2010)
# 2006    (12, 2010)
# 1079    (12, 2010)
# 2189    (12, 2010)
# 3355    (12, 2010)
# 1688    (12, 2010)
# 152     (12, 2010)
# 1703    (12, 2010)
# 903     (12, 2010)
# 1892    (12, 2010)
# 140     (12, 2010)
# 1289    (12, 2010)
# 1911    (12, 2010)
# ...

# %%
movies[movies["Month,Year"]==(3, 2012)]
# Out:
#      Release_Date                    Movie Distributor     Budget   US Gross  \
# 0      2012-03-09              John Carter         NaN  300000000   66439100
# 76     2012-03-30      Wrath of the Titans         NaN  150000000   36030512
# 280    2012-03-30            Mirror Mirror         NaN   85000000   19662216
# 351    2012-03-23         The Hunger Games         NaN   80000000  253006396
# 482    2012-03-02  Doctor Suess' The Lorax   Universal   67500000  190133010
# 2221   2012-03-30                     Womb         NaN   13000000    Unknown
# 2292   2012-03-02         Project X (2011)         NaN   12000000   53442484
#
#      Worldwide Gross Month_Year Month,Year
# 0          254439100  (3, 2010)  (3, 2012)
# 76         114030512  (3, 2010)  (3, 2012)
# 280          Unknown  (3, 2010)  (3, 2012)
# 351        384606396  (3, 2010)  (3, 2012)
# 482        227533010  (3, 2010)  (3, 2012)
# 2221         Unknown  (3, 2010)  (3, 2012)
# 2292        77642484  (3, 2010)  (3, 2012)
